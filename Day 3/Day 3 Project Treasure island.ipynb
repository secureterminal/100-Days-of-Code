# %%
print('''
 _                                     _     _                 _ 
| |                                   (_)   | |               | |
| |_ _ __ ___  __ _ ___ _   _ _ __ ___ _ ___| | __ _ _ __   __| |
| __| '__/ _ \/ _` / __| | | | '__/ _ \ / __| |/ _` | '_ \ / _` |
| |_| | |  __/ (_| \__ \ |_| | | |  __/ \__ \ | (_| | | | | (_| |
 \__|_|  \___|\__,_|___/\__,_|_|  \___|_|___/_|\__,_|_| |_|\__,_|
''')

hole = '''
       ________________________________         
      /                                "-_          
     /      .  |  .                       \          
    /      : \ | / :                       \         
   /        '-___-'                         \      
  /_________________________________________ \      
       _______| |________________________--""-L 
      /       F J                              \ 
     /       F   J                              L
    /      :'     ':                            F
   /        '-___-'                            / 
  /_________________________________________--"  
'''

crocodile = '''
                    .-._   _ _ _ _ _ _ _ _
         .-''-.__.-'00  '-' ' ' ' ' ' ' ' '-.
         '.___ '    .   .--_'-' '-' '-' _'-' '._
          V: V 'vv-'   '_   '.       .'  _..' '.'.
            '=.____.=_.--'   :_.__.__:_   '.   : :
                    (((____.-'        '-.  /   : :
          snd                         (((-'\ .' /
                                    _____..'  .'
                                   '-._____.-'

'''

beast = '''
                   (    )
                  ((((()))
                  |o\ /o)|
                  ( (  _')
                   (._.  /\__
                  ,\___,/ '  ')
    '.,_,,       (  .- .   .    )
     \   \\     ( '        )(    )
      \   \\    \.  _.__ ____( .  |
       \  /\\   .(   .'  /\  '.  )
        \(  \\.-' ( /    \/    \)
         '  ()) _'.-|/\/\/\/\/\|
             '\\ .( |\/\/\/\/\/|
               '((  \    /\    /
               ((((  '.__\/__.')
                ((,) /   ((()   )
                 "..-,  (()("   /
            pils  _//.   ((() ."
          _____ //,/" ___ ((( ', ___
                           ((  )
                            / /
                          _/,/'
                        /,/,"

'''

fire = '''
               (  .      )
           )           (              )
                 .  '   .   '  .  '  .
        (    , )       (.   )  (   ',    )
         .' ) ( . )    ,  ( ,     )   ( .
      ). , ( .   (  ) ( , ')  .' (  ,    )
     (_,) . ), ) _) _,')  (, ) '. )  ,. (' )
 jgs^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

'''

chest = '''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/_____ /
*******************************************************************************
'''

print("Welcome to Treasure Island.\n")
print("\nYour mission is to find the treasure.\n") 

#https://www.draw.io/?lightbox=1&highlight=0000ff&edit=_blank&layers=1&nav=1&title=Treasure%20Island%20Conditional.drawio#Uhttps%3A%2F%2Fdrive.google.com%2Fuc%3Fid%3D1oDe4ehjWZipYRsVfeAx2HyB7LCQ8_Fvi%26export%3Ddownload

#Write your code below this line 👇

stage1 = input('You are at a T-junction, where do you want to go? Type "Left" or "Right"\n')

if stage1.lower() == 'left':
    stage2 = input('\nYou went 2km towards your left and you are faced with a large river, the river has a portal that \
    opens once every 24 hours, do you want to swim through or wait? Type "Swim" or "Wait"\n')
    
    if stage2.lower() == 'wait':
        stage3 = input('\nYou chose to wait, and after 24 hours, a portal was opened, you were faced with 3 doors \
        A red door, A blue door and A Yellow door. Type "Red", "Blue" or "Yellow" \n')
        
        if stage3.lower() == 'red':
            print('\nYou chose the red door and immediately you were burned with fire, GAME OVER\n')
            print(fire)
            
        elif stage3.lower() == 'blue':
            print('\nYou chose the blue door and you were eaten by beasts, GAME OVER\n')
            print(beast)
            
        elif stage3.lower() == 'yellow':
            print('\nYou chose the yellow door, and just in front of you was the Tresure chest, CONGRATULATIONS YOU WIN\n')
            print(chest)
            
        else:
            print('\nWrong choice, GAME OVER\n')
            
    else:
        print('\nYou took courage and swam through the river, just when you are about to get to the other side, \
        you were attacked by a crocodile, GAME OVER\n')
        print(crocodile)
        
        
else:
    print('\nYou went towards your right and fell into a hole, GAME OVER\n')
    print(hole)
# Out:
#  _                                     _     _                 _
# | |                                   (_)   | |               | |
# | |_ _ __ ___  __ _ ___ _   _ _ __ ___ _ ___| | __ _ _ __   __| |
# | __| '__/ _ \/ _` / __| | | | '__/ _ \ / __| |/ _` | '_ \ / _` |
# | |_| | |  __/ (_| \__ \ |_| | | |  __/ \__ \ | (_| | | | | (_| |
#  \__|_|  \___|\__,_|___/\__,_|_|  \___|_|___/_|\__,_|_| |_|\__,_|
#
# Welcome to Treasure Island.
#
#
# Your mission is to find the treasure.
#
# You are at a T-junction, where do you want to go? Type "Left" or "Right"
# left
#
# You went 2km towards your left and you are faced with a large river, the river has a portal that     opens once every 24 hours, do you want to swim through or wait? Type "Swim" or "Wait"
# wait
#
# You chose to wait, and after 24 hours, a portal was opened, you were faced with 3 doors         A red door, A blue door and A Yellow door. Type "Red", "Blue" or "Yellow"
# yellow
#
# ...
